# %%
import os
from shutil import copyfile
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from scipy.spatial.distance import cosine
import numpy as np

# %%
from google.colab import drive
drive.mount("/Similar_IMG_search/")
# Out:
# Mounted at /Similar_IMG_search/

# %%
# Load VGG16 model without the top classification layer
model = VGG16(weights='imagenet', include_top=False)

def extract_features(image_path, model):
    # Load and preprocess the image
    img = load_img(image_path, target_size=(224, 224))
    img_array = img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = preprocess_input(img_array)

    # Extract features
    features = model.predict(img_array)
    return features.flatten()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
def find_top_similar_images(query_img_path, folder_path, output_folder, top_n=20):
    # Extract features of the query image
    query_features = extract_features(query_img_path, model)

    # Store distances for all images
    similarity_scores = []

    # Loop through all images in the folder
    for file_name in os.listdir(folder_path):
        file_path = os.path.join(folder_path, file_name)

        # Extract features of the image
        try:
            img_features = extract_features(file_path, model)

            # Compute cosine distance
            distance = cosine(query_features, img_features)
            similarity_scores.append((file_path, distance))
        except:
            continue

    # Sort by distance (lower distance means more similar)
    similarity_scores = sorted(similarity_scores, key=lambda x: x[1])

    # Get top N similar images
    top_similar_images = similarity_scores[:top_n]

    # Save the top similar images to the specified output folder with renamed filenames
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)  # Create the folder if it doesn't exist

    for idx, (img_path, distance) in enumerate(top_similar_images):
        # Format the new filename to include cosine similarity
        new_filename = f"{idx + 1:02d}_{distance:.4f}.jpg"
        output_path = os.path.join(output_folder, new_filename)
        copyfile(img_path, output_path)

    return top_similar_images

# %%
# Example usage
query_image = "/Similar_IMG_search/MyDrive/Find_similarity/014.jpg"  # Path to the query image
image_folder = "/Similar_IMG_search/MyDrive/Find_similarity/ascending_cluster/cluster_0/"  # Folder containing images
output_folder = "/Similar_IMG_search/MyDrive/Find_similarity/output_searched_Img/"  # Folder to save the result

top_images = find_top_similar_images(query_image, image_folder, output_folder, top_n=20)

# Print the results
print("Top 20 similar images:")
for img_path, distance in top_images:
    print(f"Image: {img_path} (Distance: {distance})")
print(f"Top 20 images saved to: {output_folder}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 809ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 639ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 713ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 718ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 614ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 694ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 992ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 917ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 521ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 544ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 537ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 523ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 532ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 549ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 526ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 518ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 623ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 967ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 870ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 531ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 982ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 653ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 553ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 545ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 547ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 568ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 563ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 550ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 760ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 914ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 691ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 543ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 538ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 553ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 541ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 538ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 537ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 526ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 540ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 548ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 890ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 966ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 922ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 546ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 547ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 530ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 559ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 528ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 523ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 540ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 528ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 529ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 710ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 975ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 923ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 761ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 527ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 545ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 541ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 542ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 544ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 550ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 544ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 545ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 543ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 534ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 993ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 898ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 584ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 548ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 550ms/step
# Top 20 similar images:
# Image: /Similar_IMG_search/MyDrive/Find_similarity/ascending_cluster/cluster_0/038.jpg (Distance: 0.38116654703369457)
# Image: /Similar_IMG_search/MyDrive/Find_similarity/ascending_cluster/cluster_0/040.jpg (Distance: 0.3851381159349069)
# Image: /Similar_IMG_search/MyDrive/Find_similarity/ascending_cluster/cluster_0/035.jpg (Distance: 0.42377131689569925)
# Image: /Similar_IMG_search/MyDrive/Find_similarity/ascending_cluster/cluster_0/042.jpg (Distance: 0.5199956705933853)
# Image: /Similar_IMG_search/MyDrive/Find_similarity/ascending_cluster/cluster_0/049.jpg (Distance: 0.5510343920775963)
# Image: /Similar_IMG_search/MyDrive/Find_similarity/ascending_cluster/cluster_0/048.jpg (Distance: 0.5549832185612236)
# Image: /Similar_IMG_search/MyDrive/Find_similarity/ascending_cluster/cluster_0/051.jpg (Distance: 0.5567056987449646)
# Image: /Similar_IMG_search/MyDrive/Find_similarity/ascending_cluster/cluster_0/053.jpg (Distance: 0.5883044519608895)
# Image: /Similar_IMG_search/MyDrive/Find_similarity/ascending_cluster/cluster_0/013.jpg (Distance: 0.589980952936652)
# Image: /Similar_IMG_search/MyDrive/Find_similarity/ascending_cluster/cluster_0/018.jpg (Distance: 0.652243943378594)
# Image: /Similar_IMG_search/MyDrive/Find_similarity/ascending_cluster/cluster_0/019.jpg (Distance: 0.6561520164214649)
# Image: /Similar_IMG_search/MyDrive/Find_similarity/ascending_cluster/cluster_0/056.jpg (Distance: 0.6578089718625578)
# Image: /Similar_IMG_search/MyDrive/Find_similarity/ascending_cluster/cluster_0/060.jpg (Distance: 0.6645114314394469)
# Image: /Similar_IMG_search/MyDrive/Find_similarity/ascending_cluster/cluster_0/062.jpg (Distance: 0.6834335451568765)
# Image: /Similar_IMG_search/MyDrive/Find_similarity/ascending_cluster/cluster_0/034.jpg (Distance: 0.6874303734088428)
# Image: /Similar_IMG_search/MyDrive/Find_similarity/ascending_cluster/cluster_0/030.jpg (Distance: 0.6898298522267468)
# Image: /Similar_IMG_search/MyDrive/Find_similarity/ascending_cluster/cluster_0/021.jpg (Distance: 0.6932110686904814)
# Image: /Similar_IMG_search/MyDrive/Find_similarity/ascending_cluster/cluster_0/066.jpg (Distance: 0.6955001596828094)
# Image: /Similar_IMG_search/MyDrive/Find_similarity/ascending_cluster/cluster_0/024.jpg (Distance: 0.6972530844544407)
# Image: /Similar_IMG_search/MyDrive/Find_similarity/ascending_cluster/cluster_0/063.jpg (Distance: 0.6986861551213519)
# Top 20 images saved to: /Similar_IMG_search/MyDrive/Find_similarity/output_searched_Img/
